# %%
# function make_moave() - checks to see if a move can be made
# inputs board, player (x or o), row, column
# returns true if move can be made false if not
def make_move(board, player, row, column):
    #TODO your code goes here
    print("make_move() not implemented yet...")

# function check_for_player - checks to see if player(checking) has won
# checks for horizontal, vertical and diagonal wins
# inputs baord and checking (x or o)
# returns true of player has won 
def check_for_player(board, checking):
    #TODO you code goes here
    print("check_for_player() not implemented yet...")
    # Check for horizontal
    #Check for vertical
    #Check Diagonals 
    
# function check_for_win - wrapper for check for player
# checks each player for win by calling check_for_player()
# inputs board, player1 (name), player2 (name) - Prints players name has won
# return true or false for won
def check_for_win(board, player1, player2):
    #TODO you code goes here
    print("check_for_win() Not implemented yet...")

# function print_board() - prints out the crrent board
# inputs board
# returns nothing
def print_board(board):
    for column_index in range(0, len(board)): 
        row = " "
        for row_index in range(0, len(board[column_index])): 
            if row_index != len(board[column_index]) -1 : 
                row += board[column_index][row_index] + " |"
            else: 
                row += board[column_index][row_index]
        print(row)
        if column_index !=len(board) -1: 
            print("----------")

# function game_loop()
# input x and o user names, sets up initial board
# calls wheck_for_win() in while loop and make_move() after user input
#
def game_loop(): 
    print("Welcome to tic-tac-toe. x's go first")
    x_name = input("What is your name x? ")
    o_name = input("What is your name o? ")
    board = [[' ', ' ', ' '], [' ', ' ', ' '], [' ', ' ', ' ']]
    turn = 'x'
    while not check_for_win(board, x_name, o_name): 
        print_board(board)
        if turn == 'x': 
            greeting = x_name 
        else: 
            greeting = o_name
        user_x = input(greeting + " which row would you like? (0-2)")
        user_y = input(greeting + " which column would you like? (0-2)")
        if user_x == "quit" or user_y == "quit": 
            return
        could_move = make_move(board, turn, int(user_x), int(user_y))
        if could_move: 
            if turn == 'x': 
                turn = 'o'
            else: 
                turn = 'x'
            
game_loop()
